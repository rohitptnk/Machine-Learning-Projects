# %%
# Installing the libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
df = pd.read_csv("C:/Users/rohit/OneDrive/Desktop/Files/Finance/Projects/ML/Loan Approval Project/train_u6lujuX_CVtuZ9i.csv")
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.sample(5)
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 579  LP002888   Male      No          0      Graduate           NaN
# 321  LP002053   Male     Yes         3+      Graduate            No
# 59   LP001199   Male     Yes          2  Not Graduate            No
# 422  LP002361   Male     Yes          0      Graduate            No
# 231  LP001768   Male     Yes          0      Graduate           NaN
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 579             3182             2917.0       161.0             360.0
# 321             4342              189.0       124.0             360.0
# 59              3357             2859.0       144.0             360.0
# 422             1820             1719.0       100.0             360.0
# 231             3716                0.0        42.0             180.0
#
#      Credit_History Property_Area Loan_Status
# 579             1.0         Urban           Y
# ...

# %%
df.shape
# Out:
# (614, 13)

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
# Checking for outliers
plt.figure(figsize=(12,8))
sns.boxplot(data = df)
# Out:
# <Axes: >

# %%
# Filling null values of numerical data

df['LoanAmount'] = df['LoanAmount'].fillna(df['LoanAmount'].median()) # using median because of outliers
df['Loan_Amount_Term'] = df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mean()) # using mean for rest of the features due to less outliers
df['Credit_History'] = df['Credit_History'].fillna(df['Credit_History'].mean())


df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
# Filling null values of categorical data with mode

df['Gender'] = df['Gender'].fillna(df['Gender'].mode()[0]) 
df['Married'] = df['Married'].fillna(df['Married'].mode()[0])
df['Dependents'] = df['Dependents'].fillna(df['Dependents'].mode()[0])
df['Self_Employed'] = df['Self_Employed'].fillna(df['Self_Employed'].mode()[0])

df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
print("No of people who took loan by Gender")
print(df['Gender'].value_counts())

sns.countplot(x='Gender',data=df, palette = 'Set1')
# Out:
# No of people who took loan by Gender
# Male      502
# Female    112
# Name: Gender, dtype: int64
# <Axes: xlabel='Gender', ylabel='count'>

# %%
print("No of people who took loan by Married")
print(df['Married'].value_counts())

sns.countplot(x='Married',data=df, palette = 'Set1')
# Out:
# No of people who took loan by Married
# Yes    401
# No     213
# Name: Married, dtype: int64
# <Axes: xlabel='Married', ylabel='count'>

# %%
print("No of people who took loan by Education")
print(df['Education'].value_counts())

sns.countplot(x='Education',data=df, palette = 'Set1')
# Out:
# No of people who took loan by Education
# Graduate        480
# Not Graduate    134
# Name: Education, dtype: int64
# <Axes: xlabel='Education', ylabel='count'>

# %%
corr = df.corr()
plt.figure(figsize = (10,8))
sns.heatmap(corr, annot = True, cmap = 'BuPu')
# Out:
# <Axes: >

# %%
# Feature Engineering

df['Total_Income'] = df['ApplicantIncome']+df['CoapplicantIncome']

df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
sns.distplot(df['ApplicantIncome'])
# Out:
# <Axes: xlabel='ApplicantIncome', ylabel='Density'>

# %%
# Applying Log Transformation
df['ApplicantIncomeLog'] = np.log(df['ApplicantIncome']+1)
sns.distplot(df['ApplicantIncomeLog'])
# Out:
# <Axes: xlabel='ApplicantIncomeLog', ylabel='Density'>

# %%
sns.distplot(df['LoanAmount'])
# Out:
# <Axes: xlabel='LoanAmount', ylabel='Density'>

# %%
df['LoanAmountLog'] = np.log(df['LoanAmount']+1)
sns.distplot(df['LoanAmountLog'])
# Out:
# <Axes: xlabel='LoanAmountLog', ylabel='Density'>

# %%
sns.distplot(df['Loan_Amount_Term'])
# Out:
# <Axes: xlabel='Loan_Amount_Term', ylabel='Density'>

# %%
df['Loan_Amount_Term_Log'] = np.log(df['Loan_Amount_Term']+1)
sns.distplot(df['Loan_Amount_Term_Log'])
# Out:
# <Axes: xlabel='Loan_Amount_Term_Log', ylabel='Density'>

# %%
sns.distplot(df['Credit_History'])
# Out:
# <Axes: xlabel='Credit_History', ylabel='Density'>

# %%
sns.distplot(df['Total_Income'])
# Out:
# <Axes: xlabel='Total_Income', ylabel='Density'>

# %%
df['Total_Income_Log'] = np.log(df['Total_Income']+1)
sns.distplot(df['Total_Income_Log'])
# Out:
# <Axes: xlabel='Total_Income_Log', ylabel='Density'>

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0       128.0             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status  Total_Income  ApplicantIncomeLog  \
# ...

# %%
# Dropping unneccesary columns

cols = ['Loan_ID', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term', 'Total_Income']
df.drop(columns = cols, inplace = True)

df.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  Credit_History  \
# 0   Male      No          0      Graduate            No             1.0
# 1   Male     Yes          1      Graduate            No             1.0
# 2   Male     Yes          0      Graduate           Yes             1.0
# 3   Male     Yes          0  Not Graduate            No             1.0
# 4   Male      No          0      Graduate            No             1.0
#
#   Property_Area Loan_Status  ApplicantIncomeLog  LoanAmountLog  \
# 0         Urban           Y            8.674197       4.859812
# 1         Rural           N            8.430327       4.859812
# 2         Urban           Y            8.006701       4.204693
# 3         Urban           Y            7.857094       4.795791
# 4         Urban           Y            8.699681       4.955827
#
#    Loan_Amount_Term_Log  Total_Income_Log
# 0              5.888878          8.674197
# 1              5.888878          8.714732
# ...

# %%
df['Property_Area'].value_counts()
# Out:
# Semiurban    233
# Urban        202
# Rural        179
# Name: Property_Area, dtype: int64

# %%
# encoding: we use label encoding as we only have a few categorical values in our categorical features

from sklearn.preprocessing import LabelEncoder
cols = ['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 'Property_Area', 'Loan_Status']
le = LabelEncoder()

for col in cols:
    df[col] = le.fit_transform(df[col])

# %%
df.sample(5)
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  Credit_History  \
# 251       0        0           2          0              0        1.000000
# 180       1        1           1          0              0        0.000000
# 582       0        1           0          0              0        1.000000
# 323       0        0           0          0              0        0.842199
# 596       1        1           2          1              1        1.000000
#
#      Property_Area  Loan_Status  ApplicantIncomeLog  LoanAmountLog  \
# 251              2            0            8.139732       4.934474
# 180              2            0            8.764210       5.198497
# 582              1            1            8.060540       3.610918
# 323              0            1            8.060540       4.890349
# 596              0            0            8.761550       5.236442
#
#      Loan_Amount_Term_Log  Total_Income_Log
# 251              5.888878          8.139732
# ...

# %%
df.dtypes
# Out:
# Gender                    int32
# Married                   int32
# Dependents                int32
# Education                 int32
# Self_Employed             int32
# Credit_History          float64
# Property_Area             int32
# Loan_Status               int32
# ApplicantIncomeLog      float64
# LoanAmountLog           float64
# Loan_Amount_Term_Log    float64
# Total_Income_Log        float64
# dtype: object

# %%
# Splitting Independent and Dependent Features

X = df.drop(columns='Loan_Status',axis=1)
y = df['Loan_Status']

# %%
X
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  Credit_History  \
# 0         1        0           0          0              0             1.0
# 1         1        1           1          0              0             1.0
# 2         1        1           0          0              1             1.0
# 3         1        1           0          1              0             1.0
# 4         1        0           0          0              0             1.0
# ..      ...      ...         ...        ...            ...             ...
# 609       0        0           0          0              0             1.0
# 610       1        1           3          0              0             1.0
# 611       1        1           1          0              0             1.0
# 612       1        1           2          0              0             1.0
# 613       0        0           0          0              1             0.0
#
# ...

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      1
# 4      1
#       ..
# 609    1
# 610    1
# 611    1
# 612    1
# 613    0
# Name: Loan_Status, Length: 614, dtype: int32

# %%
y.value_counts()
# Out:
# 1    422
# 0    192
# Name: Loan_Status, dtype: int64

# %%
# We can see that the data set is imbalanced. So, we use imbalaned_learn library to balance the data set.

# %pip install -U imbalanced_learn
# Out:
# ...
#
# ...

# %%
# we use over sampling to balance the data set.
from imblearn.over_sampling import RandomOverSampler

oversample = RandomOverSampler(random_state=42)

X_resampled, y_resampled = oversample.fit_resample(X,y)
df_resampled = pd.concat([pd.DataFrame(X_resampled, columns=X.columns),pd.Series(y_resampled, name='Loan_Status')], axis=1)

# %%
X_resampled
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  Credit_History  \
# 0         1        0           0          0              0        1.000000
# 1         1        1           1          0              0        1.000000
# 2         1        1           0          0              1        1.000000
# 3         1        1           0          1              0        1.000000
# 4         1        0           0          0              0        1.000000
# ..      ...      ...         ...        ...            ...             ...
# 839       1        1           3          1              0        1.000000
# 840       1        1           1          0              0        0.842199
# 841       1        1           1          0              0        0.000000
# 842       1        1           2          1              0        0.000000
# 843       1        0           0          0              0        0.000000
#
# ...

# %%
y_resampled
# Out:
# 0      1
# 1      0
# 2      1
# 3      1
# 4      1
#       ..
# 839    0
# 840    0
# 841    0
# 842    0
# 843    0
# Name: Loan_Status, Length: 844, dtype: int32

# %%
y_resampled.value_counts()
# Out:
# 1    422
# 0    422
# Name: Loan_Status, dtype: int64

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
# Splitting test and train sets
X_resampled_train, X_resampled_test, y_resampled_train, y_resampled_test = train_test_split(X_resampled, y_resampled, test_size=0.25, random_state=42)

# %%
# Accuracy Score of Random Forest Classifier

model1 = RandomForestClassifier()
model1.fit(X_resampled_train, y_resampled_train)
y_pred = model1.predict(X_resampled_test)
accuracy = accuracy_score(y_resampled_test, y_pred)*100
print(f'Accuracy Score for Random Forest Classifier: {accuracy:.2f}%')
# Out:
# Accuracy Score for Random Forest Classifier: 87.68%

# %%
# Cross Validation Scores for Logistic Regression

print(f'Cross Validation Score for Logistic Regression: {np.mean(cross_val_score(LogisticRegression(), X, y, cv=5))*100:.2f}%')
# Out:
# Cross Validation Score for Logistic Regression: 80.95%

# %%
# Defining a classification report function

from sklearn.metrics import classification_report

def generate_classification_report(model_name, y_test, y_pred):
    report = classification_report(y_test, y_pred)
    print(f'Classification Report for {model_name}: \n{report}\n')

# %%
# Generating classification report for all the models

models = [LogisticRegression(), DecisionTreeClassifier(), RandomForestClassifier(), KNeighborsClassifier()]

for model in models:
    model.fit(X_resampled_train, y_resampled_train)
    y_pred = model.predict(X_resampled_test)
    generate_classification_report(model, y_resampled_test, y_pred)
# Out:
# Classification Report for LogisticRegression():
#               precision    recall  f1-score   support
#
#            0       0.84      0.54      0.65       114
#            1       0.62      0.88      0.72        97
#
#     accuracy                           0.69       211
#    macro avg       0.73      0.71      0.69       211
# weighted avg       0.73      0.69      0.69       211
#
#
# Classification Report for DecisionTreeClassifier():
#               precision    recall  f1-score   support
#
#            0       0.79      0.86      0.82       114
#            1       0.82      0.73      0.77        97
#
#     accuracy                           0.80       211
#    macro avg       0.80      0.80      0.80       211
# weighted avg       0.80      0.80      0.80       211
#
#
# Classification Report for RandomForestClassifier():
#               precision    recall  f1-score   support
#
#            0       0.92      0.86      0.89       114
# ...

# %%
# Random Forest Classifier has the highest accuracy score and f1-score of 88%.
